# %% [markdown]
# <a href="https://colab.research.google.com/github/gurusaiedu/Gen-AI/blob/main/Image_gemini_hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install llama-index-multi-modal-llms-gemini
# %pip install llama-index-vector-stores-qdrant
# %pip install llama-index-embeddings-gemini
# %pip install llama-index-llms-gemini
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 32.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 49.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 22.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 50.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ...

# %%
# !pip install llama-index 'google-generativeai>=0.3.0' matplotlib qdrant_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 53.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 13.2 MB/s eta 0:00:00
# ...

# %%
import os

os.environ['GOOGLE_API_KEY'] = "AIzaSyB_VtaStDXRpaGqdahwYv-8ys-ZXHITd4s"

# %%
IMAGE_URL = "https://p.imgci.com/db/PICTURES/CMS/371200/371206.4.jpg"

# %%
from llama_index.multi_modal_llms.gemini import GeminiMultiModal

from llama_index.core.multi_modal_llms.generic_utils import load_image_urls

image_urls = [
    "https://i.pinimg.com/564x/66/bb/a8/66bba8a996d9e55f65af25279ae1bfa4.jpg"
    # "/content/gg_ceo.PNG"
    # "https://ss-i.thgim.com/public/incoming/uy142/article66607948.ece/alternates/LANDSCAPE_1200/madhana.jpg",
    #"https://www.jagranimages.com/images/newimg/15092023/15_09_2023-birthday_23530648_81724845.webp"
    # "https://www.india.com/wp-content/uploads/2023/09/PM-Modi-with-his-mother-ANI.jpg"
   # "https://p.imgci.com/db/PICTURES/CMS/371200/371206.4.jpg",
    # Add yours here!

]


image_documents = load_image_urls(image_urls)

gemini_pro = GeminiMultiModal(model_name="models/gemini-pro-vision")

# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

img_response = requests.get(image_urls[0])
print(image_urls[0])
img = Image.open(BytesIO(img_response.content))
plt.imshow(img)
# Out:
# https://i.pinimg.com/564x/66/bb/a8/66bba8a996d9e55f65af25279ae1bfa4.jpg

# %%
complete_response = gemini_pro.complete(
    prompt="List the iteams present in the images with apporimate size/weight ",
    image_documents=image_documents,
)

# %%
print(complete_response)
# Out:
#  The image contains 18 different vegetables. They are:
#
# 1. Potato (200g)
# 2. Onion (100g)
# 3. Green beans (100g)
# 4. Cucumber (200g)
# 5. Pepperoni (100g)
# 6. Tomato (100g)
# 7. Carrot (100g)
# 8. Spring onion (100g)
# 9. Lettuce (200g)
# 10. Red onion (100g)
# 11. Pumpkin (500g)
# 12. Broccoli (200g)
# 13. Chinese cabbage (200g)
# 14. Eggplant (200g)
# 15. Cucumber (200g)
# 16. Parsnip (100g)

# %% [markdown]
# # **Using loacl images**

# %%
pip install -q pillow

# %%
pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.5/810.5 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 15.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...

# %%
pip install langchain-core

# %%
pip install langchain_google_genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.3.2
#     Uninstalling google-generativeai-0.3.2:
#       Successfully uninstalled google-generativeai-0.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-embeddings-gemini 0.1.5 requires google-generativeai<0.4.0,>=0.3.2, but you have google-generativeai 0.4.1 which is incompatible.
# llama-index-llms-gemini 0.1.6 requires google-generativeai<0.4.0,>=0.3.2, but you have google-generativeai 0.4.1 which is incompatible.
# llama-index-multi-modal-llms-gemini 0.1.4 requires google-generativeai<0.4.0,>=0.3.2, but you have google-generativeai 0.4.1 which is incompatible.
# ...

# %%
from PIL import Image
img=Image.open("/content/images4")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
from langchain_google_genai import ChatGoogleGenerativeAI  # Assuming this is the correct import
llm=ChatGoogleGenerativeAI(model='gemini-pro-vision')

# %%
from langchain_core.messages import HumanMessage

# Use the HumanMessage class and other components as needed
prompt="In this image, list the ingredients visible and their estimated weight in grams (g) or kilograms (kg)."
prompt1="List the iteams present in the images "
message=HumanMessage(
    content=[
        {'type':'text','text':prompt1},
        {'type':'image_url','image_url':img}
    ]
)

# %%
reponse=llm.invoke([message])

# %%
print(reponse.content)
# Out:
#  The items present in the images are:
#
# Bananas
# Dragon fruit
# Eggs
# Meat
# Lettuce
# Strawberries
# Oranges
