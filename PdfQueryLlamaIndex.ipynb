# %% [markdown]
# <a href="https://colab.research.google.com/github/gurusaiedu/Gen-AI/blob/main/PdfQueryLlamaIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install llama-index pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 45.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 25.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 70.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 76.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 44.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 77.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.0 MB/s eta 0:00:00
# ...

# %%
pip install cohere langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.5/807.5 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.9/256.9 kB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 6.3 MB/s eta 0:00:00
# ...

# %%
from llama_index.core import SimpleDirectoryReader, ServiceContext, VectorStoreIndex

# %%
documents=SimpleDirectoryReader("/content/").load_data()

# %%
documents
# Out:
# [Document(id_='5e410690-b6b4-42ab-966d-2cca9690ec16', embedding=None, metadata={'page_label': '1', 'file_name': 'Machine Learning .pdf', 'file_path': '/content/Machine Learning .pdf', 'file_type': 'application/pdf', 'file_size': 3189728, 'creation_date': '2024-03-08', 'last_modified_date': '2024-03-08'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Python\xa0Libraries\xa0for\xa0\nData\xa0AnalysisandMachineLearning', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...

# %%
from langchain.embeddings.cohere import CohereEmbeddings

import os
os.environ["COHERE_API_KEY"] = "btu0gWrLzedOkMOrjGC1k6gEhVbIcR0GdsrNlT24"


# Define the embeddings model
embeddings = CohereEmbeddings(model = "multilingual-22-12")

# %%
pip install llama-index-embeddings-langchain

# %%
index=VectorStoreIndex.from_documents(documents,embed_model=embeddings,show_progress=True)
# Out:
# ...
# Generating embeddings:   0%|          | 0/132 [00:00<?, ?it/s]

# %%
index

# %%
import os
import getpass
import google.generativeai as genai

os.environ['GOOGLE_API_KEY'] = getpass.getpass("AIzaSyB_VtaStDXRpaGqdahwYv-8ys-ZXHITd4s")
model = genai.GenerativeModel('gemini-pro')
# Out:
# AIzaSyB_VtaStDXRpaGqdahwYv-8ys-ZXHITd4s··········

# %%
index.as_query_engine(llm=model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-c27e44518edc> in <cell line: 1>()
# ----> 1 index.as_query_engine(llm=model)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/base.py in as_query_engine(self, llm, **kwargs)
#     392         )
#     393
# --> 394         return RetrieverQueryEngine.from_args(
#     395             retriever,
#     396             llm=llm,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/query_engine/retriever_query_engine.py in from_args(cls, retriever, llm, response_synthesizer, node_postprocessors, response_mode, text_qa_template, refine_template, summary_template, simple_template, output_cls, use_async, streaming, service_context, **kwargs)
#     106         llm = llm or llm_from_settings_or_context(Settings, service_context)
#     107
# ...

# %%
pip install llama-index-llms-gemini

# %%
# set up Gemini
import os
GOOGLE_API_KEY = "YOUR_API_KEY_HERE"
os.environ["GOOGLE_API_KEY"] = "AIzaSyB_VtaStDXRpaGqdahwYv-8ys-ZXHITd4s"

# %%
# from llama_index.multi_modal_llms.gemini import GeminiMultiModal
# gemini_pro = GeminiMultiModal(model_name="models/gemini-pro-vision", safety_settings=safety_settings)
from llama_index.llms import Gemini

gemini = Gemini(model_name="models/gemini-pro", temperature=0.2, max_tokens=2048)

from llama_index.embeddings import GeminiEmbedding
gemini_embedding = GeminiEmbedding(model_name="models/embedding-001")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-3fbac0c06720> in <cell line: 3>()
#       1 # from llama_index.multi_modal_llms.gemini import GeminiMultiModal
#       2 # gemini_pro = GeminiMultiModal(model_name="models/gemini-pro-vision", safety_settings=safety_settings)
# ----> 3 from llama_index.llms import Gemini
#       4
#       5 gemini = Gemini(model_name="models/gemini-pro", temperature=0.2, max_tokens=2048)
#
# ImportError: cannot import name 'Gemini' from 'llama_index.llms' (unknown location)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

documents = SimpleDirectoryReader("/content/").load_data()
index = VectorStoreIndex.from_documents(documents,embeddings=embeddings)
query_engine = index.as_query_engine()
response = query_engine.query("What did the author do growing up?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/llama_index/core/embeddings/utils.py in resolve_embed_model(embed_model, callback_manager)
#      58             embed_model = OpenAIEmbedding()
# ---> 59             validate_openai_api_key(embed_model.api_key)
#      60         except ImportError:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/embeddings/openai/utils.py in validate_openai_api_key(api_key)
#     103     if not openai_api_key:
# --> 104         raise ValueError(MISSING_API_KEY_ERROR_MESSAGE)
#
# ValueError: No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
#
# During handling of the above exception, another exception occurred:
#
# ...
